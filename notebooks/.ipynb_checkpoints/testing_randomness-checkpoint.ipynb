# %% [markdown]
# # **AUTOMATIC CONFIG FILE**

# %%
# some_file.py
import sys

CODE_DIR = "../"
sys.path.insert(1, CODE_DIR)

# %%
from importlib import reload
from pandas import DataFrame
import files
import study_phase
import test_phase

# %% [markdown]
# # 1

# %%
arqs = files.Files()

studyPhase = study_phase.StudyPhase(
    arqs, random_state=arqs.random_seed
)

studyPhaseImageSequence = studyPhase.getLinearImageSequence(shuffleImages=True)

images_df = DataFrame.from_records(
    studyPhaseImageSequence,
    columns=[
        "file_name",
        "file_path",
        "file_category",
        "exposure_time_ms"
    ]
)

images_df.loc[:10, :]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-2f39ff572cb8> in <module>
#       3
#       4 studyPhaseImageSequence = (
# ----> 5     studyPhase.getLinearImageSequence(
#       6         shuffleImages=True,
#       7         random_state=arqs.random_seed
#
# TypeError: getLinearImageSequence() got an unexpected keyword argument 'random_state'

# %%
n = 4
k_ini = 8
k_end = k_ini + 2*n - 1

images_df.loc[k_ini:k_end, :]
# Out:
#     file_name                                          file_path  \
# 8   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 9    P031.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 10  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 11   N043.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 12  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 13   N036.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 14  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 15   N047.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
#
#    file_category  exposure_time_ms
# 8          cross              1000
# 9       positive              2000
# 10         cross              1000
# 11       neutral              2000
# 12         cross              1000
# 13       neutral              2000
# 14         cross              1000
# 15       neutral              2000

# %%
images_df.tail(20)
# Out:
#      file_name                                          file_path  \
# 116  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 117   P008.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 118  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 119   N033.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 120  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 121   A037.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 122  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 123  Sp084.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 124  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 125   N031.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 126  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 127   H034.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 128  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# ...

# %% [markdown]
# # 2

# %%
# reload(files)
# reload(study_phase)
# reload(test_phase)

arqs = files.Files()
studyPhase = study_phase.StudyPhase(arqs)

studyPhaseImageSequence = (
    studyPhase.getLinearImageSequence(
        shuffleImages=True,
        random_state=arqs.random_seed
    )
)

images_df = DataFrame.from_records(
    studyPhaseImageSequence,
    columns=[
        "file_name",
        "file_path",
        "file_category",
        "exposure_time_ms"
    ]
)

images_df.loc[:10, :]
# Out:
#     file_name                                          file_path  \
# 0   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 1    N002.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 2   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 3    N004.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 4   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 5    N008.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 6   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 7    N013.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 8   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 9    P031.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 10  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
#
#      file_category  exposure_time_ms
# 0            cross              1000
# 1   buffer_stimuli              2000
# 2            cross              1000
# ...

# %%
n = 4
k_ini = 8
k_end = k_ini + 2*n - 1

images_df.loc[k_ini:k_end, :]
# Out:
#     file_name                                          file_path  \
# 8   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 9    P031.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 10  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 11   N043.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 12  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 13   N036.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 14  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 15   N047.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
#
#    file_category  exposure_time_ms
# 8          cross              1000
# 9       positive              2000
# 10         cross              1000
# 11       neutral              2000
# 12         cross              1000
# 13       neutral              2000
# 14         cross              1000
# 15       neutral              2000

# %%
images_df.tail(20)
# Out:
#      file_name                                          file_path  \
# 116  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 117   P008.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 118  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 119   N033.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 120  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 121   A037.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 122  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 123  Sp084.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 124  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 125   N031.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 126  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 127   H034.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 128  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# ...
