# %% [markdown]
# # **Testing the randomness within trainning and test phases.**

# %%
# some_file.py
import sys
CODE_DIR = "../"
sys.path.insert(1, CODE_DIR)

# %%
from importlib import reload
from pandas import DataFrame
import files
import study_phase
import test_phase

# %% [markdown]
# ## **Testing the randomness within trainning and test phases.**

# %% [markdown]
# ### 1

# %%
arqs = files.Files()

studyPhase = study_phase.StudyPhase(
    arqs, random_state=arqs.random_seed
)

studyPhaseImageSequence = studyPhase.getLinearImageSequence(shuffleImages=True)

images_df = DataFrame.from_records(
    studyPhaseImageSequence,
    columns=[
        "file_name",
        "file_path",
        "file_category",
        "exposure_time_ms"
    ]
)

images_df.loc[:10, :]
# Out:
#     file_name                                          file_path  \
# 0   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 1    N002.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 2   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 3    N004.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 4   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 5    N008.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 6   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 7    N013.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 8   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 9    N033.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 10  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
#
#      file_category  exposure_time_ms
# 0            cross              1000
# 1   buffer_stimuli              2000
# 2            cross              1000
# 3   buffer_stimuli              2000
# 4            cross              1000
# 5   buffer_stimuli              2000
# 6            cross              1000
# 7   buffer_stimuli              2000
# 8            cross              1000
# 9          neutral              2000
# 10           cross              1000

# %%
n = 4
k_ini = 8
k_end = k_ini + 2*n - 1

images_df.loc[k_ini:k_end, :]
# Out:
#     file_name                                          file_path  \
# 8   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 9    N033.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 10  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 11   A057.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 12  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 13   N030.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 14  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 15   P022.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
#
#                file_category  exposure_time_ms
# 8                      cross              1000
# 9                    neutral              2000
# 10                     cross              1000
# 11  negative_animal_concerns              2000
# 12                     cross              1000
# 13                   neutral              2000
# 14                     cross              1000
# 15                  positive              2000

# %%
images_df.tail(20)
# Out:
#      file_name                                          file_path  \
# 116  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 117   P014.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 118  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 119  Sp084.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 120  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 121   H023.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 122  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 123   H034.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 124  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 125   N047.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 126  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 127   P018.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 128  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 129   N015.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 130  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 131   N017.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 132  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 133   N018.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 134  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 135   N021.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
#
#                file_category  exposure_time_ms
# 116                    cross              1000
# 117                 positive              2000
# 118                    cross              1000
# 119         negative_spiders              2000
# 120                    cross              1000
# 121  negative_human_concerns              2000
# 122                    cross              1000
# 123  negative_human_concerns              2000
# 124                    cross              1000
# 125                  neutral              2000
# 126                    cross              1000
# 127                 positive              2000
# 128                    cross              1000
# 129           buffer_stimuli              2000
# 130                    cross              1000
# 131           buffer_stimuli              2000
# 132                    cross              1000
# 133           buffer_stimuli              2000
# 134                    cross              1000
# 135           buffer_stimuli              2000

# %% [markdown]
# ## 2

# %%
arqs = files.Files()

studyPhase = study_phase.StudyPhase(
    arqs, random_state=arqs.random_seed
)

studyPhaseImageSequence = studyPhase.getLinearImageSequence(shuffleImages=True)

images_df = DataFrame.from_records(
    studyPhaseImageSequence,
    columns=[
        "file_name",
        "file_path",
        "file_category",
        "exposure_time_ms"
    ]
)

images_df.loc[:10, :]
# Out:
#     file_name                                          file_path  \
# 0   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 1    N002.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 2   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 3    N004.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 4   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 5    N008.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 6   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 7    N013.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 8   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 9   Sp087.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 10  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
#
#        file_category  exposure_time_ms
# 0              cross              1000
# 1     buffer_stimuli              2000
# 2              cross              1000
# 3     buffer_stimuli              2000
# 4              cross              1000
# 5     buffer_stimuli              2000
# 6              cross              1000
# 7     buffer_stimuli              2000
# 8              cross              1000
# 9   negative_spiders              2000
# 10             cross              1000

# %%
n = 4
k_ini = 8
k_end = k_ini + 2*n - 1

images_df.loc[k_ini:k_end, :]
# Out:
#     file_name                                          file_path  \
# 8   cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 9   Sp087.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 10  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 11   N039.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 12  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 13  Sn054.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 14  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 15   P022.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
#
#        file_category  exposure_time_ms
# 8              cross              1000
# 9   negative_spiders              2000
# 10             cross              1000
# 11           neutral              2000
# 12             cross              1000
# 13   negative_snakes              2000
# 14             cross              1000
# 15          positive              2000

# %%
images_df.tail(20)
# Out:
#      file_name                                          file_path  \
# 116  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 117   N030.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 118  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 119   A037.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 120  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 121   P015.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 122  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 123   P009.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 124  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 125   H034.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 126  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 127   A010.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 128  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 129   N015.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 130  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 131   N017.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 132  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 133   N018.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
# 134  cross.jpg   /home/prietoab/sussuarana/clientes/davi/imagens/
# 135   N021.bmp  /home/prietoab/sussuarana/clientes/davi/imagen...
#
#                 file_category  exposure_time_ms
# 116                     cross              1000
# 117                   neutral              2000
# 118                     cross              1000
# 119  negative_animal_concerns              2000
# 120                     cross              1000
# 121                  positive              2000
# 122                     cross              1000
# 123                  positive              2000
# 124                     cross              1000
# 125   negative_human_concerns              2000
# 126                     cross              1000
# 127  negative_animal_concerns              2000
# 128                     cross              1000
# 129            buffer_stimuli              2000
# 130                     cross              1000
# 131            buffer_stimuli              2000
# 132                     cross              1000
# 133            buffer_stimuli              2000
# 134                     cross              1000
# 135            buffer_stimuli              2000
